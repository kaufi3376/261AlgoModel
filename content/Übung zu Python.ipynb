# %% [markdown]
# # Übung zu Python

# %% [markdown]
# Wir möchten in dieser Übung nochmal genau untersuchen, wie man einen Programmablaufplan in ein Python Programm umwandelt.

# %% [markdown]
# Ein Jupyter Notebook unterscheidet sich im Umgang mit Python von einer normalen Python-Umgebung wie folgt:
#
# <ul>
#
# <li> <b> Zellen statt eines durchgehenden Skripts: </b>
# Der Code wird in Zellen geschrieben, die unabhängig voneinander ausgeführt werden können. Du musst nicht das gesamte Programm auf einmal laufen lassen, sondern kannst einzelne Teile testen.
# </li>
#
# <li> <b> Direkte Ausgabe von Ergebnissen: </b>
# Ergebnisse, wie Berechnungen, Diagramme oder Texte, erscheinen direkt unter der Zelle, in der der Code ausgeführt wurde. Du musst nicht in die Konsole wechseln oder ein zusätzliches Fenster öffnen.
#
#
# </ul>

# %% [markdown]
# <b> Klappe nun Aufgabe 1 auf </b>

# %% [markdown]
# ## Aufgabe 1

# %% [markdown]
# Führe diese Zelle aus indem du die Zelle anwählst und wenn diese markierst ist, oben auf das Play-Symbol drückst.

# %%
print("Guten Morgen")

# %% [markdown]
# ## Aufgabe 2

# %% [markdown]
# Es soll eine Kaffeemaschine in Python simuliert werden.
# Erstelle das zum Programmablaufplan passende Programm in der Sprache Python.

# %% [markdown]
# ![Screenshot 2025-01-21 161026.png](attachment:bfd5f733-e30e-4f08-ad5b-494ff19bb013.png)

# %% [markdown]
# Erstelle das zum Programmablaufplan passende Programm in der Sprache Python.

# %% [markdown]
# ## Aufgabe 3

# %% [markdown]
# Eine Firma, die für den Druck von Glückskekssprüchen zuständig ist, möchte zur Vereinfachung des Produktionsablaufes ein Programm verwenden.

# %% [markdown]
# ![Unbenannt.PNG](attachment:2f1f5dfa-8882-4ac0-ab62-bb2a17500bcb.PNG)

# %% [markdown]
# Erstelle das zum Programmablaufplan passende Programm in der Sprache Python

# %% [markdown]
# ## Aufgabe 4

# %% [markdown]
# Es haben sich in den folgenden Codeblöcken Fehler eingeschlichen. <br>
# Verbessere die Fehler, damit der Code wieder ausgeführt werden kann.

# %%
#a)
print(Hier stimmt etwas nicht)
# Out:
#   Cell In[7], line 2
#     print(Hier stimmt etwas nicht)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#b)
for i in range(4)
    print("Hello")
# Out:
#   Cell In[8], line 2
#     for i in range(4)
#                      ^
# SyntaxError: expected ':'

# %%
#c
def begrüßen(name, wieoft):
    for i in range(wieoft):
        print("Hallo", name)

begrüßen("Martin")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       3     for i in range(wieoft):
#       4         print("Hallo", name)
# ----> 6 begrüßen("Martin")
#
# TypeError: begrüßen() missing 1 required positional argument: 'wieoft'

# %% [markdown]
# ## Aufgabe 5

# %% [markdown]
# Programmiere eine Funktion dreieck(), die den Flächeninhalt eines Dreiecks aus den übergebenen Paramterwerten berechnet und das ERgebnis bei einem Aufruf an das Hauptprogramm zurückgibt. Im Hauptprogramm sollen die Maßzahlen für die Länge der Grundlinie und die Höhe zur Grundlinie als Benutzereingaben entgegengenommen werden

# %% [markdown]
# ## Aufgabe 6

# %% [markdown]
# Es soll nun ein Zinseszinsrechner für Aktien erstellt werden.
# Programmablauf:
# <ul>
# <li>	1. Hierbei soll der Benutzer zuerst gefragt werden, welchen Betrag er anlegen möchte. Dieser wird in die Variable mit dem Namen anfangskapital gespeichert. </li>
# <li>2.	Als nächstes soll der Benutzer gefragt werden, welchen Zinssatz er erwartet (z. B. 5 oder 7 ohne Prozentzeichen)</li>
# Dieser wird in die Variable mit dem Namen zinssatz gespeichert.</li>
# <li>3.	Als nächstes soll der Benutzer gefragt werden, wie lange die Anlagedauer ist.</li>
# <li>4.	Dieser wird in die Variable mit dem Namen anlagedauer gespeichert.</li>
# <li>5.	Mit Hilfe einer Funktion soll dann berechnet werden, wie hoch sein Endkapital ist. Hierbei wird folgende Funktion verwendet.
# endkapital= anfangskapital
# for jahre in range(anlagedauer):
# 	neueskapital = neueskapital * (1+zinssatz/100)
# </li>
# <li>6.	Die Variable neueskapital wird mit einem freundlichen Satz ausgegeben.</li>
# </ul>
# a)	Erstelle einen PAP mit dem PAPDesigner. <br>
# b)	Schreibe ein Python Programm, welches den Zinseszinsrechner überführt.
